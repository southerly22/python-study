# %%
import pandas as pd

# %%
df2 = pd.read_excel(io="./OTT&抖音联投数据需求.xlsx")

# print(df2.to_string)
# Out:
# 0         2023 Coke With Meal 2 Campaign
# 1         2023 Coke With Meal 2 Campaign
# 2             2023 MMJ Thematic Campaign
# 3             2023 MMJ Thematic Campaign
# 4    2023 MMJ Sparkling juice 2 Campaign
# 5    2023 MMJ Sparkling juice 2 Campaign
# 6             2023 Fanta Summer Campaign
# 7             2023 Fanta Summer Campaign
# Name: Campaign Name, dtype: object

# %%
print(df2['Campaign Name'])
# Out:
# 0         2023 Coke With Meal 2 Campaign
# 1         2023 Coke With Meal 2 Campaign
# 2             2023 MMJ Thematic Campaign
# 3             2023 MMJ Thematic Campaign
# 4    2023 MMJ Sparkling juice 2 Campaign
# 5    2023 MMJ Sparkling juice 2 Campaign
# 6             2023 Fanta Summer Campaign
# 7             2023 Fanta Summer Campaign
# Name: Campaign Name, dtype: object

# %%
# print(df2.to_string)

# %%
print(df2['Campaign Name'] +'_'+ df2['市场'])
# Out:
# 0         2023 Coke With Meal 2 Campaign_National-程序化
# 1          2023 Coke With Meal 2 Campaign_National-抖音
# 2             2023 MMJ Thematic Campaign_National-程序化
# 3              2023 MMJ Thematic Campaign_National-抖音
# 4    2023 MMJ Sparkling juice 2 Campaign_National-程序化
# 5     2023 MMJ Sparkling juice 2 Campaign_National-抖音
# 6             2023 Fanta Summer Campaign_National-程序化
# 7              2023 Fanta Summer Campaign_National-抖音
# dtype: object

# %%
df3 = pd.read_csv("./ant-learn-python/5分钟学会Python爬取天气数据/beijing_tianqi_2021.csv")

# %%
print(df3.to_string)
# Out:
# <bound method DataFrame.to_string of             ymd  high  low tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2021-01-01     1  -11      晴       东北风     1级   54       良         2
# 1    2021-01-02     0   -9   晴~多云       东北风     1级   78       良         2
# 2    2021-01-03    -1   -8     多云       东北风     1级   31       优         1
# 3    2021-01-04     0  -11   多云~晴       西北风     3级   36       优         1
# 4    2021-01-05    -2  -11      晴       西北风     2级   32       优         1
# ..          ...   ...  ...    ...       ...    ...  ...     ...       ...
# 360  2021-12-27     6   -8      晴       西北风     1级   56       良         2
# 361  2021-12-28     6   -5   多云~晴       西北风     1级   64       良         2
# 362  2021-12-29     5   -5      晴       西北风     3级   43       优         1
# 363  2021-12-30     6   -7      晴       西北风     3级   38       优         1
# 364  2021-12-31     5   -7      晴       东北风     1级   44       优         1
#
# [365 rows x 9 columns]>

# %%
df3.head()
# Out:
#           ymd  high  low tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2021-01-01     1  -11      晴       东北风     1级   54       良         2
# 1  2021-01-02     0   -9   晴~多云       东北风     1级   78       良         2
# 2  2021-01-03    -1   -8     多云       东北风     1级   31       优         1
# 3  2021-01-04     0  -11   多云~晴       西北风     3级   36       优         1
# 4  2021-01-05    -2  -11      晴       西北风     2级   32       优         1

# %%
df3.set_index('ymd',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/cr/2vb5tqmx0rz7b006j5pnyvww0000gn/T/ipykernel_64728/2679457174.py in ?()
# ----> 1 df3.set_index('ymd',inplace=True)
#
# ~/codetools/conda/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['ymd'] are in the columns"

# %%
df3.index
# Out:
# Index(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04', '2021-01-05',
#        '2021-01-06', '2021-01-07', '2021-01-08', '2021-01-09', '2021-01-10',
#        ...
#        '2021-12-22', '2021-12-23', '2021-12-24', '2021-12-25', '2021-12-26',
#        '2021-12-27', '2021-12-28', '2021-12-29', '2021-12-30', '2021-12-31'],
#       dtype='object', name='ymd', length=365)

# %%
df3.head()
# Out:
#             high  low tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2021-01-01     1  -11      晴       东北风     1级   54       良         2
# 2021-01-02     0   -9   晴~多云       东北风     1级   78       良         2
# 2021-01-03    -1   -8     多云       东北风     1级   31       优         1
# 2021-01-04     0  -11   多云~晴       西北风     3级   36       优         1
# 2021-01-05    -2  -11      晴       西北风     2级   32       优         1

# %%
df4 = pd.read_csv("./ant-learn-python/5分钟学会Python爬取天气数据/beijing_tianqi_2018.csv")

# %%
df4.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1

# %%
df4.set_index('ymd',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/cr/2vb5tqmx0rz7b006j5pnyvww0000gn/T/ipykernel_64728/1430421259.py in ?()
# ----> 1 df4.set_index('ymd',inplace=True)
#
# ~/codetools/conda/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['ymd'] are in the columns"

# %%
df4.loc[:,"bWendu"]= df4["bWendu"].str.replace("℃","").astype('int32')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df4.loc[:,"bWendu"]= df4["bWendu"].str.replace("℃","").astype('int32')
#
# File ~/codetools/conda/lib/python3.11/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~/codetools/conda/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
df4.loc[:,"yWendu"]= df4["yWendu"].str.replace("℃","").astype('int32')

# %%
df4.head()
# Out:
#            bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-01      3     -6   晴~多云       东北风   1-2级   59       良         2
# 2018-01-02      2     -5   阴~多云       东北风   1-2级   49       优         1
# 2018-01-03      2     -5     多云        北风   1-2级   28       优         1
# 2018-01-04      0     -8      阴       东北风   1-2级   28       优         1
# 2018-01-05      3     -6   多云~晴       西北风   1-2级   50       优         1

# %%
df4.loc[df4["bWendu"]<3,:]
# Out:
#            bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-02      2     -5   阴~多云       东北风   1-2级   49       优         1
# 2018-01-03      2     -5     多云        北风   1-2级   28       优         1
# 2018-01-04      0     -8      阴       东北风   1-2级   28       优         1
# 2018-01-06      2     -5   多云~阴       西南风   1-2级   32       优         1
# 2018-01-07      2     -4   阴~多云       西南风   1-2级   59       良         2
# 2018-01-08      2     -6      晴       西北风   4-5级   50       优         1
# 2018-01-09      1     -8      晴       西北风   3-4级   34       优         1
# 2018-01-10     -2    -10      晴       西北风   1-2级   26       优         1
# 2018-01-11     -1    -10      晴        北风   1-2级   24       优         1
# 2018-01-12      2     -8      晴       西南风   1-2级   75       良         2
# 2018-01-15      2     -5      阴       东南风   1-2级   47       优         1
# 2018-01-21      0     -5   阴~小雪       东北风   1-2级   63       良         2
# ...

# %%
df4["bWendu"]<3
# Out:
# ymd
# 2018-01-01    False
# 2018-01-02     True
# 2018-01-03     True
# 2018-01-04     True
# 2018-01-05    False
#               ...
# 2018-12-27     True
# 2018-12-28     True
# 2018-12-29     True
# 2018-12-30     True
# 2018-12-31     True
# Name: bWendu, Length: 365, dtype: bool

# %%
df4.loc['2018-01-01','bWendu']
# Out:
# 3

# %%
df4.loc['2018-01-01',['bWendu','yWendu']]
# Out:
# bWendu     3
# yWendu    -6
# Name: 2018-01-01, dtype: object

# %%
df4.loc[['2018-01-01','2018-01-02','2018-01-03'],['bWendu','yWendu']]
# Out:
#            bWendu yWendu
# ymd
# 2018-01-01      3     -6
# 2018-01-02      2     -5
# 2018-01-03      2     -5

# %%
df4.loc['2018-01-02':'2018-03-01',['bWendu','yWendu']]
# Out:
#            bWendu yWendu
# ymd
# 2018-01-02      2     -5
# 2018-01-03      2     -5
# 2018-01-04      0     -8
# 2018-01-05      3     -6
# 2018-01-06      2     -5
# 2018-01-07      2     -4
# 2018-01-08      2     -6
# 2018-01-09      1     -8
# 2018-01-10     -2    -10
# 2018-01-11     -1    -10
# 2018-01-12      2     -8
# 2018-01-13      3     -7
# 2018-01-14      6     -5
# 2018-01-15      2     -5
# 2018-01-16      4     -5
# 2018-01-17      6     -7
# 2018-01-18      5     -6
# 2018-01-19      7     -4
# 2018-01-20      3     -6
# 2018-01-21      0     -5
# 2018-01-22     -3    -10
# 2018-01-23     -4    -12
# 2018-01-24     -4    -11
# 2018-01-25     -3    -11
# 2018-01-26     -3    -10
# 2018-01-27     -1     -9
# 2018-01-28     -1     -9
# 2018-01-29      1     -8
# 2018-01-30      4     -7
# 2018-01-31      3     -8
# 2018-02-01      4     -7
# 2018-02-02     -1     -9
# 2018-02-03      0     -9
# 2018-02-04      1     -8
# 2018-02-05      0    -10
# ...

# %%
df4.loc['2018-01-02':'2018-03-01','bWendu':'fengxiang']
# Out:
#            bWendu yWendu tianqi fengxiang
# ymd
# 2018-01-02      2     -5   阴~多云       东北风
# 2018-01-03      2     -5     多云        北风
# 2018-01-04      0     -8      阴       东北风
# 2018-01-05      3     -6   多云~晴       西北风
# 2018-01-06      2     -5   多云~阴       西南风
# 2018-01-07      2     -4   阴~多云       西南风
# 2018-01-08      2     -6      晴       西北风
# 2018-01-09      1     -8      晴       西北风
# 2018-01-10     -2    -10      晴       西北风
# 2018-01-11     -1    -10      晴        北风
# 2018-01-12      2     -8      晴       西南风
# 2018-01-13      3     -7     多云        南风
# 2018-01-14      6     -5   晴~多云       西北风
# 2018-01-15      2     -5      阴       东南风
# 2018-01-16      4     -5     多云        南风
# 2018-01-17      6     -7   多云~晴       西北风
# 2018-01-18      5     -6      晴       西南风
# 2018-01-19      7     -4      晴        南风
# 2018-01-20      3     -6   晴~多云        东风
# 2018-01-21      0     -5   阴~小雪       东北风
# 2018-01-22     -3    -10  小雪~多云        东风
# ...

# %%
df4.loc[(df4['bWendu']<=30)&(df4['yWendu']>=15)&(df4['tianqi']=='晴'),:]
# Out:
#            bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-04-28     27     17      晴       西南风   3-4级  125    轻度污染         3
# 2018-05-13     30     17      晴        南风   1-2级   68       良         2
# 2018-05-23     29     15      晴       西南风   3-4级  153    中度污染         4
# 2018-05-28     30     16      晴       西北风   4-5级  178    中度污染         4
# 2018-08-24     30     20      晴        北风   1-2级   40       优         1
# 2018-09-03     30     19      晴        北风   3-4级   70       良         2
# 2018-09-07     27     16      晴       西北风   3-4级   22       优         1
# 2018-09-09     28     16      晴       西南风   1-2级   51       良         2

# %%
(df4['bWendu']<=30)&(df4['yWendu']>=15)&(df4['tianqi']=='晴')
# Out:
# ymd
# 2018-01-01    False
# 2018-01-02    False
# 2018-01-03    False
# 2018-01-04    False
# 2018-01-05    False
#               ...
# 2018-12-27    False
# 2018-12-28    False
# 2018-12-29    False
# 2018-12-30    False
# 2018-12-31    False
# Length: 365, dtype: bool

# %%
# 编写函数
def query_my_data(df):
    return df.index.str.startswith("2018-09") & (df['tianqi'] == '晴')

df4.loc[query_my_data,:]
# Out:
#            bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-09-03     30     19      晴        北风   3-4级   70       良         2
# 2018-09-04     31     18      晴       西南风   3-4级   24       优         1
# 2018-09-07     27     16      晴       西北风   3-4级   22       优         1
# 2018-09-09     28     16      晴       西南风   1-2级   51       良         2
# 2018-09-21     25     14      晴       西北风   3-4级   50       优         1
# 2018-09-22     24     13      晴       西北风   3-4级   28       优         1
# 2018-09-23     23     12      晴       西北风   4-5级   28       优         1
# 2018-09-24     23     11      晴        北风   1-2级   28       优         1
# 2018-09-29     22     11      晴        北风   3-4级   21       优         1
