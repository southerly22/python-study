# %%
import pandas as pd
df = pd.read_csv("./ant-learn-python/5分钟学会Python爬取天气数据/beijing_tianqi_2018.csv")

# %%
df.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1

# %%
# 默认升序
df['aqi'].sort_values()
# Out:
# 271     21
# 281     21
# 249     22
# 272     22
# 301     22
#       ...
# 317    266
# 71     287
# 91     287
# 72     293
# 86     387
# Name: aqi, Length: 365, dtype: int64

# %%
df['aqi'].sort_values(ascending=False)
# Out:
# 86     387
# 72     293
# 71     287
# 91     287
# 317    266
#       ...
# 249     22
# 301     22
# 272     22
# 271     21
# 281     21
# Name: aqi, Length: 365, dtype: int64

# %%
# df单列排序
df.sort_values(by='bWendu')
# Out:
#             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 32   2018-02-02    -1℃    -9℃      晴        北风   3-4级   32       优         1
# 344  2018-12-11    -1℃   -10℃      晴       西北风     3级   56       良         2
# 342  2018-12-09    -1℃   -10℃   多云~晴       东南风     1级   62       良         2
# 27   2018-01-28    -1℃    -9℃      晴       西北风   3-4级   55       良         2
# 26   2018-01-27    -1℃    -9℃     多云        南风   1-2级  105    轻度污染         3
# ..          ...    ...    ...    ...       ...    ...  ...     ...       ...
# 352  2018-12-19     9℃    -5℃   晴~多云       西北风     1级   59       良         2
# 351  2018-12-18     9℃    -4℃      晴       西北风     2级   53       良         2
# 60   2018-03-02     9℃    -1℃   晴~多云        北风   1-2级   95       良         2
# 324  2018-11-21     9℃    -3℃      晴       西北风     2级   43       优         1
# 323  2018-11-20     9℃    -1℃     多云        北风   1-2级   74       良         2
#
# [365 rows x 9 columns]

# %%
# df多列排序
df.sort_values(by=['bWendu','aqi'],ascending=True)
# Out:
#             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 10   2018-01-11    -1℃   -10℃      晴        北风   1-2级   24       优         1
# 32   2018-02-02    -1℃    -9℃      晴        北风   3-4级   32       优         1
# 27   2018-01-28    -1℃    -9℃      晴       西北风   3-4级   55       良         2
# 344  2018-12-11    -1℃   -10℃      晴       西北风     3级   56       良         2
# 342  2018-12-09    -1℃   -10℃   多云~晴       东南风     1级   62       良         2
# ..          ...    ...    ...    ...       ...    ...  ...     ...       ...
# 60   2018-03-02     9℃    -1℃   晴~多云        北风   1-2级   95       良         2
# 327  2018-11-24     9℃    -3℃      晴       西南风     1级  114    轻度污染         3
# 58   2018-02-28     9℃    -2℃   多云~晴       西南风   3-4级  139    轻度污染         3
# 330  2018-11-27     9℃    -3℃   晴~多云       西北风     2级  198    中度污染         4
# 335  2018-12-02     9℃     2℃   雾~多云       东北风     1级  234    重度污染         5
#
# [365 rows x 9 columns]

# %%
# 多列排序 bwendu升序，aqi降序
df.sort_values(by=['bWendu','aqi'],ascending=[True,False])
# Out:
#             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 26   2018-01-27    -1℃    -9℃     多云        南风   1-2级  105    轻度污染         3
# 342  2018-12-09    -1℃   -10℃   多云~晴       东南风     1级   62       良         2
# 344  2018-12-11    -1℃   -10℃      晴       西北风     3级   56       良         2
# 27   2018-01-28    -1℃    -9℃      晴       西北风   3-4级   55       良         2
# 32   2018-02-02    -1℃    -9℃      晴        北风   3-4级   32       优         1
# ..          ...    ...    ...    ...       ...    ...  ...     ...       ...
# 320  2018-11-17     9℃    -2℃   多云~晴       西南风   1-2级   66       良         2
# 352  2018-12-19     9℃    -5℃   晴~多云       西北风     1级   59       良         2
# 351  2018-12-18     9℃    -4℃      晴       西北风     2级   53       良         2
# 324  2018-11-21     9℃    -3℃      晴       西北风     2级   43       优         1
# 52   2018-02-22     9℃    -4℃     多云       西南风   1-2级   42       优         1
#
# [365 rows x 9 columns]
